# %% [markdown]
# <a href="https://colab.research.google.com/github/sitthatkaja/DPDM2023/blob/main/midterm_dpdm2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Use the latest Thai's general election data here https://docs.google.com/spreadsheets/d/1fROfZuM7150UjGEQksRMkoVxZ4dBYDTR/edit?usp=share_link&ouid=115237908096743617902&rtpof=true&sd=true
#
# (***Thai's general election detail***: Of the 500 members of the House of Representatives to be elected, 400 seats are elected from single-member constituencies by first-past-the-post voting, and 100 party-list seats—filled separately—are voted on in a separate ballot. ELECTED constituency candidate is the constituency candidate who recieved the highest votes, the party list is vote for the party)
#
# to write excutable codes for the following instructions,
#
#
# 1. create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by the number of votes they received and showed only top 10 (30 points)
# 2. create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by voted they received and showed only 5 worst perform (30 points)
# 3. create a table from the party list vote result that shows the ratio between the vote recieved by the highest party and the second highest party of each constituency area.
#
#  ($\frac{V1}{V2}$ where $V1$ is the number of votes the highest paty received and $V2$ is the number of votes the second highest paty received)
#
# The table should include name of the constituency area, district, province, name of the top party, name of the runner-up party, and $\frac{V1}{V2}$
# (60 points)
#
# Full score 100 points (bonus 20 points)

# %% [markdown]
# ##Input Data
#
# โดยใช้ pd ในการเปิดตาราง

# %%
import pandas as pd

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ข้อมูลที่ 1 : ข้อมูลผลโหวตการเลือกตั้งประเภทแบบแบ่งเขต (Candidate)

# %%
table_candidate = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/ectreport66.xlsx - result_Candidate.csv')
table_candidate
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id
# 0          706
# 1          709
# 2          712
# 3          742
# 4          761
# ...        ...
# ...

# %% [markdown]
# ข้อมูลที่ 2 : ข้อมูลผลโหวตการเลือกตั้งประเภทแบบพรรคพวก (Partylist)

# %%
table_party = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/ectreport66.xlsx - result_PartyList.csv')
table_party
# Out:
#       cons_id  party_id  party_list_vote  party_list_vote_percent
# 0       ACR_1       701             4550                  4.30977
# 1       ACR_1       702              185                  0.17523
# 2       ACR_1       703               67                  0.06346
# 3       ACR_1       705            33576                 31.80328
# 4       ACR_1       706              132                  0.12503
# ...       ...       ...              ...                      ...
# 26795   YST_3       780              145                  0.13871
# 26796   YST_3       781              412                  0.39414
# 26797   YST_3       783               17                  0.01626
# 26798   YST_3       784              138                  0.13202
# 26799   YST_3       786               85                  0.08131
#
# [26800 rows x 4 columns]

# %% [markdown]
# ข้อมูลที่ 3 : ชื่อพรรค

# %%
name_party = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/ectreport66.xlsx - info_party_overview.csv')
new_name = name_party[['id','name']]
new_name
# Out:
#      id           name
# 0   701   ประชาธิปัตย์
# 1   702     ประชากรไทย
# 2   703   ความหวังใหม่
# 3   705       เพื่อไทย
# 4   706  ชาติพัฒนากล้า
# ..  ...            ...
# 65  780    ไทยก้าวหน้า
# 66  781           พลัง
# 67  783  ชาติรุ่งเรือง
# 68  784       รวมใจไทย
# 69  786        เปลี่ยน
#
# [70 rows x 2 columns]

# %% [markdown]
# ข้อมูลที่ 4 ชื่อในแต่ละเขตของแบบแบ่งเขต

# %%
name_car = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/ectreport66.xlsx - Candidate_Constituency.csv')
name_car
# Out:
#      mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0      ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1     ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2     ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3     ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4     ACR_1_13        นายสงบ โสภิพันธ์         13              761
# ...        ...                     ...        ...              ...
# 4776   YST_3_5       นายธนพัฒน์ ศรีชนะ          5              709
# 4777   YST_3_6        นายพิทยา พาลุสุข          6              763
# 4778   YST_3_7      นายศรายุทธ สุดสวาท          7              712
# 4779   YST_3_8    นางสาวสุนันทา สีชมภู          8              769
# 4780   YST_3_9        นายณัฐพล ศรีอุบล          9              726
#
#                                               image_url
# 0     https://cdn.ectreport.com/images/mp_candidates...
# ...

# %% [markdown]
# #Data preprocessing
#
# เช็ค missing value ทั้ง 3 ตาราง

# %%
table_candidate.isnull().any() # ไม่มีค่า missing value
# Out:
# cons_id                False
# mp_app_id              False
# mp_app_rank            False
# mp_app_vote            False
# mp_app_vote_percent    False
# party_id               False
# dtype: bool

# %%
table_party.isnull().any() #ไม่มีค่า missing value
# Out:
# cons_id                    False
# party_id                   False
# party_list_vote            False
# party_list_vote_percent    False
# dtype: bool

# %%
new_name.isnull().any() #ไม่มีค่า missing value
# Out:
# id      False
# name    False
# dtype: bool

# %% [markdown]
# ดังนั้นสรุปได้ว่า ทั้ง 3 ตารางได้แก่ประเภทแบบแบ่งเขต ประเภทแบบพรรคพวก และรายชื่อพรรค ไม่มีค่า missing value อยู่จึงสามารถนำข้อมูลไปใช้ต่อได้

# %% [markdown]
# # รวมตาราง
#
# ทำการรวมตารางให้มีชื่อโชว์ว่าพรรคไหนเป็นพรรคที่ได้โดยที่เทียบกับ party_id

# %%
table_candidate['name'] = table_candidate['party_id'].map(new_name.set_index('id')['name'])
table_candidate
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id             name
# 0          706    ชาติพัฒนากล้า
# 1          709        ภูมิใจไทย
# ...

# %%
table_candidate['car_name'] = table_candidate['mp_app_id'].map(name_car.set_index('mp_app_id')['mp_app_name'])
table_candidate
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id             name                car_name
# 0          706    ชาติพัฒนากล้า   นางสาวปิยะมาศ บัวแก้ว
# ...

# %%
table_party['name'] = table_party['party_id'].map(new_name.set_index('id')['name'])
table_party
# Out:
#       cons_id  party_id  party_list_vote  party_list_vote_percent  \
# 0       ACR_1       701             4550                  4.30977
# 1       ACR_1       702              185                  0.17523
# 2       ACR_1       703               67                  0.06346
# 3       ACR_1       705            33576                 31.80328
# 4       ACR_1       706              132                  0.12503
# ...       ...       ...              ...                      ...
# 26795   YST_3       780              145                  0.13871
# 26796   YST_3       781              412                  0.39414
# 26797   YST_3       783               17                  0.01626
# 26798   YST_3       784              138                  0.13202
# 26799   YST_3       786               85                  0.08131
#
#                 name
# 0       ประชาธิปัตย์
# 1         ประชากรไทย
# 2       ความหวังใหม่
# 3           เพื่อไทย
# 4      ชาติพัฒนากล้า
# ...              ...
# ...

# %% [markdown]
# ***

# %% [markdown]
# #1.
# create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by the number of votes they received and showed only top 10 (30 points)
#
# สร้างตารางที่แสดงรายการเลือกตั้งแบบแบ่งเขตเลือกตั้งและพรรคพวก เรียงตารางตามจำนวนโหวตที่ได้รับและแสดงเฉพาะ 10 อันดับแรก (30 คะแนน)

# %% [markdown]
# ## 1.1 ตารางแสดงแบบแบ่งเขต

# %% [markdown]
# ทำการหาค่าผลรวมโหวตของแต่ละพรรคว่ามีผลโหวตรวมเป็นยังไง

# %%
candidate = table_candidate.groupby('name').sum().reset_index()[['name','mp_app_vote']]
candidate
# Out:
# <ipython-input-221-4c6b958dc594>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   candidate = table_candidate.groupby('name').sum().reset_index()[['name','mp_app_vote']]
#                   name  mp_app_vote
# 0                 กรีน         1597
# 1              ก้าวไกล      9535709
# 2   ครูไทยเพื่อประชาชน         4278
# 3              คลองไทย        48265
# 4         ความหวังใหม่         1195
# ..                 ...          ...
# 65           ไทยรวมไทย         1054
# 66        ไทยศรีวิไลย์        33554
# 67           ไทยสมาร์ท        12299
# 68         ไทยสร้างไทย       870538
# 69        ไทยเป็นหนึ่ง         2504
#
# [70 rows x 2 columns]

# %% [markdown]
# จากนั้นจะใช้จำนวนโหวตไปเรียงลำดับโดยใช้ list ของผลโหวตทั้งหมดไปหา

# %%
len(list(candidate['mp_app_vote']))
# Out:
# 70

# %% [markdown]
# loop ด้วยการ sort ด้วยวิธี bubble sort จากมากไปน้อย

# %%
list_can1 = list(candidate['mp_app_vote'])
n = len(list_can1)

for i in range(n - 1):
    for j in range(0, n - i - 1):
        if list_can1[j] < list_can1[j + 1]:
            list_can1[j], list_can1[j + 1] = list_can1[j + 1], list_can1[j]

print(list_can1)
# Out:
# [9535709, 9222908, 5015210, 4127116, 3521377, 2231142, 870538, 584802, 311057, 297294, 273669, 95867, 94345, 89287, 48265, 43926, 33554, 20756, 20017, 19591, 17240, 13570, 12299, 11709, 9559, 8418, 4972, 4457, 4317, 4278, 4058, 3191, 2807, 2504, 2397, 2262, 2071, 1930, 1621, 1597, 1593, 1577, 1556, 1467, 1355, 1307, 1203, 1200, 1195, 1152, 1054, 957, 934, 889, 876, 796, 707, 637, 460, 431, 427, 352, 330, 296, 232, 216, 132, 77, 65, 0]

# %% [markdown]
# จากนั้นนำ list ที่ได้ไปสร้างตารางเป็น dataframe อันใหม่

# %%
dfcan1 = pd.DataFrame(list_can1, columns=["vote"])
dfcan1
# Out:
#        vote
# 0   9535709
# 1   9222908
# 2   5015210
# 3   4127116
# 4   3521377
# ..      ...
# 65      216
# 66      132
# 67       77
# 68       65
# 69        0
#
# [70 rows x 1 columns]

# %% [markdown]
# แล้วเอา dataframe ไปเทียบกับตารางพรรคนั้นๆว่าอยู่พรรคไหนจำนวน 10 พรรคแรก

# %%
dfcan1['name'] = dfcan1['vote'].map(candidate.set_index('mp_app_vote')['name'])
dfcan1.head(10)
# Out:
#       vote             name
# 0  9535709          ก้าวไกล
# 1  9222908         เพื่อไทย
# 2  5015210        ภูมิใจไทย
# 3  4127116     พลังประชารัฐ
# 4  3521377  รวมไทยสร้างชาติ
# 5  2231142     ประชาธิปัตย์
# 6   870538      ไทยสร้างไทย
# 7   584802     ชาติไทยพัฒนา
# 8   311057        ประชาชาติ
# 9   297294    ชาติพัฒนากล้า

# %% [markdown]
# สรุปว่าในการเลือกตั้งแบบแบ่งเขต พบว่า พรรคที่ได้คะแนนมากที่สุด 10 อันดับแรกเรียงตามอันดับได้แก่
# 1. ก้าวไกล
# 2. เพื่อไทย
# 3. ภูมิใจไทย
# 4. พลังประชารัฐ
# 5. รวมไทยสร้างชาติ
# 6. ประชาธิปัตย์
# 7. ไทยสร้างไทย
# 8. ชาติไทยพัฒนา
# 9. ประชาชาติ
# 10. ชาติพัฒนากล้า

# %% [markdown]
# ##1.2 ตารางแสดงแบบพรรคพวก
#
# ทำการหาค่าผลรวมโหวตของแต่ละพรรคว่ามีผลโหวตรวมเป็นยังไง

# %%
party = table_party.groupby('name').sum().reset_index()[['name','party_list_vote']]
party
# Out:
# <ipython-input-226-a6bbdd6b18ef>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   party = table_party.groupby('name').sum().reset_index()[['name','party_list_vote']]
#                   name  party_list_vote
# 0                 กรีน            21559
# 1              ก้าวไกล         14233895
# 2   ครูไทยเพื่อประชาชน           172963
# 3              คลองไทย             7835
# 4         ความหวังใหม่            10687
# ..                 ...              ...
# 62           ไทยรวมไทย            71854
# 63        ไทยศรีวิไลย์            23404
# 64           ไทยสมาร์ท            10235
# 65         ไทยสร้างไทย           338042
# 66        ไทยเป็นหนึ่ง            13424
#
# [67 rows x 2 columns]

# %% [markdown]
# จากนั้นจะใช้จำนวนโหวตไปเรียงลำดับโดยใช้ list ของผลโหวตทั้งหมดไปหา

# %%
len(list(set(party['party_list_vote'])))
# Out:
# 67

# %% [markdown]
# loop ด้วยการ sort ด้วยวิธี bubble sort มากไปน้อย

# %%
list_par1 = list(set(party['party_list_vote']))
n = len(list_par1)

for i in range(n - 1):
    for j in range(0, n - i - 1):
        if list_par1[j] < list_par1[j + 1]:
            list_par1[j], list_par1[j + 1] = list_par1[j + 1], list_par1[j]

print(list_par1)
# Out:
# [14233895, 10865836, 4673691, 1121595, 899303, 576613, 530017, 347607, 338042, 266799, 246177, 207860, 197543, 191308, 181699, 174897, 172963, 154602, 132858, 128586, 102237, 82660, 80712, 78789, 71854, 71765, 66830, 59109, 57514, 56655, 52863, 44773, 43655, 34559, 33607, 33394, 33157, 31645, 23404, 23042, 21559, 20803, 17460, 16898, 13424, 12451, 11673, 10995, 10687, 10550, 10541, 10303, 10235, 10017, 9893, 9005, 8679, 7835, 7688, 6463, 6126, 5773, 5480, 5454, 4962, 4497, 3382]

# %% [markdown]
# จากนั้นนำ list ที่ได้ไปสร้างตารางเป็น dataframe อันใหม่

# %%
dfpar1 = pd.DataFrame(list_par1, columns=["vote"])
dfpar1
# Out:
#         vote
# 0   14233895
# 1   10865836
# 2    4673691
# 3    1121595
# 4     899303
# ..       ...
# 62      5480
# 63      5454
# 64      4962
# 65      4497
# 66      3382
#
# [67 rows x 1 columns]

# %% [markdown]
# แล้วเอา dataframe ไปเทียบกับตารางพรรคนั้นๆว่าอยู่พรรคไหนจำนวน 10 พรรคแรก

# %%
dfpar1['name'] = dfpar1['vote'].map(party.set_index('party_list_vote')['name'])
dfpar1.head(10)
# Out:
#        vote             name
# 0  14233895          ก้าวไกล
# 1  10865836         เพื่อไทย
# 2   4673691  รวมไทยสร้างชาติ
# 3   1121595        ภูมิใจไทย
# 4    899303     ประชาธิปัตย์
# 5    576613        ประชาชาติ
# 6    530017     พลังประชารัฐ
# 7    347607       เสรีรวมไทย
# 8    338042      ไทยสร้างไทย
# 9    266799  ประชาธิปไตยใหม่

# %% [markdown]
# สรุปว่าในการเลือกตั้งแบบพรรคพวก พบว่า พรรคที่ได้คะแนนมากที่สุด 10 อันดับแรกเรียงตามอันดับได้แก่
# 1. ก้าวไกล
# 2. เพื่อไทย
# 3. รวมไทยสร้างชาติ
# 4. ภูมิใจไทย
# 5. ประชาธิปัตย์
# 6. ประชาชาติ
# 7. พลังประชารัฐ
# 8. เสรีรวมไทย
# 9. ไทยสร้างไทย
# 10. ประชาธิปไตยใหม่

# %% [markdown]
# ***

# %% [markdown]
# #2.
#
# create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by voted they received and showed only 5 worst perform (30 points)
#
# สร้างตารางที่แสดงรายการเลือกตั้งแบบแบ่งเขตเลือกตั้งและพรรคพวก จัดเรียงตารางตามการโหวตที่พวกเขาได้รับ และแสดงผลงานแย่ที่สุดเพียง 5 รายการ (30 คะแนน)

# %% [markdown]
# ## 2.1 ตารางแสดงแบบแบ่งเขต

# %% [markdown]
# ใช้ตารางเดิมที่เคยหา

# %%
candidate
# Out:
#                   name  mp_app_vote
# 0                 กรีน         1597
# 1              ก้าวไกล      9535709
# 2   ครูไทยเพื่อประชาชน         4278
# 3              คลองไทย        48265
# 4         ความหวังใหม่         1195
# ..                 ...          ...
# 65           ไทยรวมไทย         1054
# 66        ไทยศรีวิไลย์        33554
# 67           ไทยสมาร์ท        12299
# 68         ไทยสร้างไทย       870538
# 69        ไทยเป็นหนึ่ง         2504
#
# [70 rows x 2 columns]

# %% [markdown]
# loop โดยการเรียงจากน้อยไปมาก

# %%
list_can2 = list(candidate['mp_app_vote'])
n = len(list_can2)

for i in range(n - 1):
    for j in range(0, n - i - 1):
        if list_can2[j] > list_can2[j + 1]:
            list_can2[j], list_can2[j + 1] = list_can2[j + 1], list_can2[j]

print(list_can2)
# Out:
# [0, 65, 77, 132, 216, 232, 296, 330, 352, 427, 431, 460, 637, 707, 796, 876, 889, 934, 957, 1054, 1152, 1195, 1200, 1203, 1307, 1355, 1467, 1556, 1577, 1593, 1597, 1621, 1930, 2071, 2262, 2397, 2504, 2807, 3191, 4058, 4278, 4317, 4457, 4972, 8418, 9559, 11709, 12299, 13570, 17240, 19591, 20017, 20756, 33554, 43926, 48265, 89287, 94345, 95867, 273669, 297294, 311057, 584802, 870538, 2231142, 3521377, 4127116, 5015210, 9222908, 9535709]

# %% [markdown]
# สร้างตารางใหม่ขึ้นมา

# %%
dfcan2 = pd.DataFrame(list_can2, columns=["vote"])
dfcan2
# Out:
#        vote
# 0         0
# 1        65
# 2        77
# 3       132
# 4       216
# ..      ...
# 65  3521377
# 66  4127116
# 67  5015210
# 68  9222908
# 69  9535709
#
# [70 rows x 1 columns]

# %% [markdown]
# นำไปรวมกับตารางแล้วแสดงผลออกมา 5 ผลแรกที่แย่ที่สุด

# %%
dfcan2['name'] = dfcan2['vote'].map(candidate.set_index('mp_app_vote')['name'])
dfcan2.head(5)
# Out:
#    vote              name
# 0     0           สามัญชน
# 1    65      ประชาสามัคคี
# 2    77  ภาคีเครือข่ายไทย
# 3   132    พลังไทยรักชาติ
# 4   216        พลังสหกรณ์

# %% [markdown]
# สรุปว่าในการเลือกตั้งแบบแบ่งเขต พบว่า พรรคที่ได้คะแนนน้อยที่สุด 5 อันดับแรกเรียงตามอันดับได้แก่
# 1. สามัญชน
# 2. ประชาสามัคคี
# 3. ภาคีเครือข่ายไทย
# 4. พลังไทยรักชาติ
# 5. พลังสหกรณ์

# %% [markdown]
# ##2.2 ตารางแสดงแบบพรรคพวก
#
# ทำการหาค่าผลรวมโหวตของแต่ละพรรคว่ามีผลโหวตรวมเป็นยังไง

# %% [markdown]
# ใช้ตารางเดิมที่เคยหา

# %%
party
# Out:
#                   name  party_list_vote
# 0                 กรีน            21559
# 1              ก้าวไกล         14233895
# 2   ครูไทยเพื่อประชาชน           172963
# 3              คลองไทย             7835
# 4         ความหวังใหม่            10687
# ..                 ...              ...
# 62           ไทยรวมไทย            71854
# 63        ไทยศรีวิไลย์            23404
# 64           ไทยสมาร์ท            10235
# 65         ไทยสร้างไทย           338042
# 66        ไทยเป็นหนึ่ง            13424
#
# [67 rows x 2 columns]

# %% [markdown]
# loop โดยการเรียงจากน้อยไปมาก

# %%
list_par2 = list(set(party['party_list_vote']))
n = len(list_par2)

for i in range(n - 1):
    for j in range(0, n - i - 1):
        if list_par2[j] > list_par2[j + 1]:
            list_par2[j], list_par2[j + 1] = list_par2[j + 1], list_par2[j]

print(list_par2)
# Out:
# [3382, 4497, 4962, 5454, 5480, 5773, 6126, 6463, 7688, 7835, 8679, 9005, 9893, 10017, 10235, 10303, 10541, 10550, 10687, 10995, 11673, 12451, 13424, 16898, 17460, 20803, 21559, 23042, 23404, 31645, 33157, 33394, 33607, 34559, 43655, 44773, 52863, 56655, 57514, 59109, 66830, 71765, 71854, 78789, 80712, 82660, 102237, 128586, 132858, 154602, 172963, 174897, 181699, 191308, 197543, 207860, 246177, 266799, 338042, 347607, 530017, 576613, 899303, 1121595, 4673691, 10865836, 14233895]

# %% [markdown]
# สร้างตารางใหม่ขึ้นมา

# %%
dfpar2 = pd.DataFrame(list_par2, columns=["vote"])
dfpar2
# Out:
#         vote
# 0       3382
# 1       4497
# 2       4962
# 3       5454
# 4       5480
# ..       ...
# 62    899303
# 63   1121595
# 64   4673691
# 65  10865836
# 66  14233895
#
# [67 rows x 1 columns]

# %% [markdown]
# นำไปรวมกับตารางแล้วแสดงผลออกมา 5 ผลแรกที่แย่ที่สุด

# %%
dfpar2['name'] = dfpar2['vote'].map(party.set_index('party_list_vote')['name'])
dfpar2.head(5)
# Out:
#    vote              name
# 0  3382          ภราดรภาพ
# 1  4497     ชาติรุ่งเรือง
# 2  4962      พลังปวงชนไทย
# 3  5454  ถิ่นกาขาวชาววิไล
# 4  5480         พลังสังคม

# %% [markdown]
# สรุปว่าในการเลือกตั้งแบบพรรคพวก พบว่า พรรคที่ได้คะแนนน้อยที่สุด 5 อันดับแรกเรียงตามอันดับได้แก่
# 1. ภราดรภาพ
# 2. ชาติรุ่งเรื่อง
# 3. พลังปวงชนไทย
# 4. ถื่นกาขาวชาววิไล
# 5. พลังสังคม

# %% [markdown]
# ****

# %% [markdown]
# 3. create a table from the party list vote result that shows the ratio between the vote recieved by the highest party and the second highest party of each constituency area.
#
#  ($\frac{V1}{V2}$ where $V1$ is the number of votes the highest paty received and $V2$ is the number of votes the second highest paty received)
#
# The table should include name of the constituency area, district, province, name of the top party, name of the runner-up party, and $\frac{V1}{V2}$
# (60 points)
#
# สร้างตารางจากผลการลงคะแนนแบบบัญชีรายชื่อพรรคที่แสดงอัตราส่วนระหว่างคะแนนเสียงที่ได้รับจากพรรคสูงสุดกับพรรคสูงสุดอันดับสองของแต่ละพื้นที่เขตเลือกตั้ง
#
#   ($\frac{V1}{V2}$ โดยที่ $V1$ คือจำนวนโหวตที่ Paty สูงสุดได้รับ และ $V2$ คือจำนวนโหวตที่ Paty สูงสุดเป็นอันดับสองได้รับ)
#
# ตารางควรประกอบด้วยชื่อเขตเลือกตั้ง อำเภอ จังหวัด ชื่อพรรคชั้นนำ ชื่อพรรครองชนะเลิศ และ $\frac{V1}{V2}$
# (60 คะแนน)

# %%
table_candidate
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id             name                car_name
# 0          706    ชาติพัฒนากล้า   นางสาวปิยะมาศ บัวแก้ว
# ...

# %% [markdown]
# คะแนนพรรคอันดับ 1 ในแต่ละเขตคือ

# %%
rankone = table_candidate [table_candidate ['mp_app_rank']==1]
rankone
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 14     ACR_2  ACR_2_10            1        46881             41.92804
# 32     ATG_1   ATG_1_8            1        44725             49.82954
# 40     ATG_2   ATG_2_8            1        47232             51.63886
# 49     AYA_1   AYA_1_7            1        41081             37.23905
# ...      ...       ...          ...          ...                  ...
# 4717   YLA_2  YLA_2_11            1        51946             51.78082
# 4731   YLA_3  YLA_3_10            1        31741             32.40332
# 4744   YST_1   YST_1_1            1        53130             48.08536
# 4766   YST_2   YST_2_6            1        44851             45.56547
# 4776   YST_3   YST_3_5            1        37946             36.30085
#
#       party_id         name                 car_name
# 1          709    ภูมิใจไทย   นางสุขสมรวย วันทนียกุล
# ...

# %% [markdown]
# คะแนนพรรคอันดับ 2 ในแต่ละเขตคือ

# %%
ranktwo = table_candidate [table_candidate ['mp_app_rank']==2]
ranktwo
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 11     ACR_1   ACR_1_8            2        21388             20.25878
# 13     ACR_2   ACR_2_1            2        19188             17.16080
# 31     ATG_1   ATG_1_7            2        20828             23.20513
# 36     ATG_2   ATG_2_4            2        21459             23.46118
# 50     AYA_1   AYA_1_8            2        35676             32.33953
# ...      ...       ...          ...          ...                  ...
# 4725   YLA_2   YLA_2_5            2        24611             24.53274
# 4741   YLA_3   YLA_3_7            2        24885             25.40426
# 4751   YST_1   YST_1_4            2        25214             22.81996
# 4769   YST_2   YST_2_9            2        34581             35.13187
# 4773   YST_3   YST_3_2            2        25205             24.11223
#
#       party_id          name                   car_name
# 11         705      เพื่อไทย          นางสมหญิง บัวบุตร
# ...

# %%
a = rankone.iloc[-1,3]/ranktwo.iloc[-1,3]
a
# Out:
# 1.505494941479865

# %%
listrank = []

for i in range(1,399):
        list_rank = rankone.iloc[i,3]/ranktwo.iloc[i,3]
        print(list_rank)
        list_A.append()
        print('---')
# Out:
# 2.443245778611632
# ---
# 2.147349721528711
# ---
# 2.2010345309660284
# ---
# 1.1515024105841463
# ---
# 1.0247351141620653
# ---
# 1.3623930141105713
# ---
# 1.6116886042544976
# ---
# 1.2375498007968126
# ---
# 2.0501615464651444
# ---
# 1.7034056553441224
# ---
# 1.6628450678895783
# ---
# 2.4578436107980464
# ---
# 1.9355503764790247
# ---
# 1.4509716251074807
# ---
# 1.2767682514846557
# ---
# 1.4801740990741765
# ---
# 1.5890890107021665
# ---
# 2.1020495303159694
# ---
# 1.5688413948256468
# ---
# 2.2977440250167525
# ---
# 1.0001151244783422
# ---
# 2.7254485935984483
# ---
# 2.6307015936984794
# ---
# 2.6300400980173757
# ---
# 2.637390829694323
# ---
# 1.2637198907375218
# ---
# 2.3504769595719983
# ---
# 2.1427347865187785
# ---
# 1.7973488424789457
# ---
# 2.0242130750605325
# ---
# 2.1128104657776654
# ---
# 2.0297716150081566
# ---
# 1.9648981665749248
# ---
# 2.3011848847139196
# ---
# 2.425864290315654
# ---
# 2.239133351220821
# ---
# 2.967833312350497
# ---
# ...
