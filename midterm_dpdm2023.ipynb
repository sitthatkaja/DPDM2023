# %% [markdown]
# <a href="https://colab.research.google.com/github/sitthatkaja/DPDM2023/blob/main/midterm_dpdm2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Use the latest Thai's general election data here https://docs.google.com/spreadsheets/d/1fROfZuM7150UjGEQksRMkoVxZ4dBYDTR/edit?usp=share_link&ouid=115237908096743617902&rtpof=true&sd=true
#
# (***Thai's general election detail***: Of the 500 members of the House of Representatives to be elected, 400 seats are elected from single-member constituencies by first-past-the-post voting, and 100 party-list seats—filled separately—are voted on in a separate ballot. ELECTED constituency candidate is the constituency candidate who recieved the highest votes, the party list is vote for the party)
#
# to write excutable codes for the following instructions,
#
#
# 1. create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by the number of votes they received and showed only top 10 (30 points)
# 2. create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by voted they received and showed only 5 worst perform (30 points)
# 3. create a table from the party list vote result that shows the ratio between the vote recieved by the highest party and the second highest party of each constituency area.
#
#  ($\frac{V1}{V2}$ where $V1$ is the number of votes the highest paty received and $V2$ is the number of votes the second highest paty received)
#
# The table should include name of the constituency area, district, province, name of the top party, name of the runner-up party, and $\frac{V1}{V2}$
# (60 points)
#
# Full score 100 points (bonus 20 points)

# %% [markdown]
# ##Input Data
#
# โดยใช้ pd ในการเปิดตาราง

# %%
import pandas as pd

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ข้อมูลที่ 1 : ข้อมูลผลโหวตการเลือกตั้งประเภทแบบแบ่งเขต (Candidate)

# %%
table_candidate = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/ectreport66.xlsx - result_Candidate.csv')
table_candidate
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id
# 0          706
# 1          709
# 2          712
# 3          742
# 4          761
# ...        ...
# ...

# %% [markdown]
# ข้อมูลที่ 2 : ข้อมูลผลโหวตการเลือกตั้งประเภทแบบพรรคพวก (Partylist)

# %%
table_party = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/ectreport66.xlsx - result_PartyList.csv')
table_party
# Out:
#       cons_id  party_id  party_list_vote  party_list_vote_percent
# 0       ACR_1       701             4550                  4.30977
# 1       ACR_1       702              185                  0.17523
# 2       ACR_1       703               67                  0.06346
# 3       ACR_1       705            33576                 31.80328
# 4       ACR_1       706              132                  0.12503
# ...       ...       ...              ...                      ...
# 26795   YST_3       780              145                  0.13871
# 26796   YST_3       781              412                  0.39414
# 26797   YST_3       783               17                  0.01626
# 26798   YST_3       784              138                  0.13202
# 26799   YST_3       786               85                  0.08131
#
# [26800 rows x 4 columns]

# %% [markdown]
# #Data preprocessing
#
# เช็ค missing value ทั้ง 2 ตาราง

# %%
table_candidate.isnull().any() # ไม่มีค่า missing value
# Out:
# cons_id                False
# mp_app_id              False
# mp_app_rank            False
# mp_app_vote            False
# mp_app_vote_percent    False
# party_id               False
# dtype: bool

# %%
table_party.isnull().any() #ไม่มีค่า missing value
# Out:
# cons_id                    False
# party_id                   False
# party_list_vote            False
# party_list_vote_percent    False
# dtype: bool

# %% [markdown]
# ดังนั้นสรุปได้ว่า ทั้ง 2 ตารางได้แก่ประเภทแบบแบ่งเขตและประเภทแบบพรรคพวก ไม่มีค่า missing value อยู่จึงสามารถนำข้อมูลไปใช้ต่อได้

# %% [markdown]
# ***
